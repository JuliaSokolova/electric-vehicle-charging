# %% [markdown]
# #  Finding the average sizes of user requests for each user (in kWh)
#
# 1. Group data set by the hour of arrival
# 2. Calculate average request size for each hour
# 3. Plot the change dynamic into a graph

# %%
import pandas as pd
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import seaborn as sns

# %%
#changong data types to datetime format for users table
#dropping sessions with requests higher than 90 kWh (there are no cars with batteries bigger than 90 kWh)

users_to_clean = pd.read_csv('./data/users.csv')
users_to_clean['Modified'] = pd.to_datetime(users_to_clean.modifiedAt, infer_datetime_format=True)  
users_to_clean['Departure'] = pd.to_datetime(users_to_clean.requestedDeparture, infer_datetime_format=True)

users_drop = users_to_clean.drop(columns = ['requestedDeparture', 'modifiedAt', 'Unnamed: 0'])
users = users_drop[users_drop.kWhRequested <= 90]
users.head()
# Out:
#    WhPerMile  kWhRequested  milesRequested  minutesAvailable  paymentRequired  \
# 0        350          59.5             170               550             True
# 1        400           8.0              20                60             True
# 2        400           8.0              20               648             True
# 3        400          28.0              70               648             True
# 4        350          17.5              50               546             True
#
#    userID                  Modified                 Departure
# 0      22 2018-04-30 15:08:54+00:00 2018-05-01 00:17:49+00:00
# 1      61 2018-05-07 14:38:32+00:00 2018-05-07 15:38:18+00:00
# 2      61 2018-05-07 15:40:44+00:00 2018-05-08 01:26:18+00:00
# 3      61 2018-05-07 15:41:04+00:00 2018-05-08 01:26:18+00:00
# 4      22 2018-05-11 15:18:23+00:00 2018-05-12 00:23:01+00:00

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16820 entries, 0 to 17133
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   WhPerMile         16820 non-null  int64
#  1   kWhRequested      16820 non-null  float64
#  2   milesRequested    16820 non-null  int64
#  3   minutesAvailable  16820 non-null  int64
#  4   paymentRequired   16820 non-null  bool
#  5   userID            16820 non-null  int64
#  6   Modified          16820 non-null  datetime64[ns, UTC]
#  7   Departure         16820 non-null  datetime64[ns, UTC]
# dtypes: bool(1), datetime64[ns, UTC](2), float64(1), int64(4)
# memory usage: 1.0 MB

# %%
#changing data types to datetime format for users table

charging_to_clean = pd.read_csv('./data/charging.csv')
charging_to_clean['ConnectionTime'] = pd.to_datetime(charging_to_clean.connectionTime, infer_datetime_format=True) 
charging_to_clean['DisconnectTime'] = pd.to_datetime(charging_to_clean.disconnectTime, infer_datetime_format=True) 
charging_to_clean['DoneCharging'] = pd.to_datetime(charging_to_clean.doneChargingTime, infer_datetime_format=True) 

charging = charging_to_clean.drop(columns = ['connectionTime', 'disconnectTime', 'doneChargingTime', 'Unnamed: 0'])
charging.head()
# Out:
#                         _id  clusterID  kWhDelivered  \
# 0  5bc90cb9f9af8b0d7fe77cd2         39         7.932
# 1  5bc90cb9f9af8b0d7fe77cd3         39        10.013
# 2  5bc90cb9f9af8b0d7fe77cd4         39         5.257
# 3  5bc90cb9f9af8b0d7fe77cd5         39         5.177
# 4  5bc90cb9f9af8b0d7fe77cd6         39        10.119
#
#                                 sessionID  siteID spaceID    stationID  \
# 0  2_39_78_362_2018-04-25 11:08:04.400812       2  CA-496  2-39-78-362
# 1   2_39_95_27_2018-04-25 13:45:09.617470       2  CA-319   2-39-95-27
# 2  2_39_79_380_2018-04-25 13:45:49.962001       2  CA-489  2-39-79-380
# 3  2_39_79_379_2018-04-25 14:37:06.460772       2  CA-327  2-39-79-379
# 4  2_39_79_381_2018-04-25 14:40:33.638896       2  CA-490  2-39-79-381
#
#               timezone  userID            ConnectionTime  \
# 0  America/Los_Angeles     NaN 2018-04-25 11:08:04+00:00
# 1  America/Los_Angeles     NaN 2018-04-25 13:45:10+00:00
# 2  America/Los_Angeles     NaN 2018-04-25 13:45:50+00:00
# 3  America/Los_Angeles     NaN 2018-04-25 14:37:06+00:00
# 4  America/Los_Angeles     NaN 2018-04-25 14:40:34+00:00
#
#              DisconnectTime              DoneCharging
# 0 2018-04-25 13:20:10+00:00 2018-04-25 13:21:10+00:00
# 1 2018-04-26 00:56:16+00:00 2018-04-25 16:44:15+00:00
# 2 2018-04-25 23:04:45+00:00 2018-04-25 14:51:44+00:00
# 3 2018-04-25 23:55:34+00:00 2018-04-25 16:05:22+00:00
# 4 2018-04-25 23:03:12+00:00 2018-04-25 17:40:30+00:00

# %%
hours = list(range(24))

# %%
users.describe()
# Out:
#           WhPerMile  kWhRequested  milesRequested  minutesAvailable  \
# count  16820.000000  16820.000000    16820.000000      16820.000000
# mean     367.755767     20.087768       60.563020        282.444233
# std      100.522602     14.774043       52.962184        179.516089
# min      200.000000      2.000000       10.000000          1.000000
# 25%      292.000000      8.000000       20.000000        129.000000
# 50%      400.000000     16.000000       40.000000        253.000000
# 75%      400.000000     27.000000       80.000000        422.000000
# max      600.000000     90.000000      300.000000       1913.000000
#
#              userID
# count  16820.000000
# mean    1111.334602
# std      940.484846
# min        1.000000
# 25%      564.000000
# 50%      850.000000
# 75%     1249.000000
# max     6952.000000

# %% [markdown]
# ## Group data by user ID

# %%
users_ID = users.groupby(['userID'])
users_ID.describe().T
# Out:
# userID                   1           17          22     43     45    \
# WhPerMile        count    1.0    2.000000   70.000000    1.0    1.0
#                  mean   500.0  346.000000  352.142857  217.0  250.0
#                  std      NaN    0.000000   10.199866    NaN    NaN
#                  min    500.0  346.000000  350.000000  217.0  250.0
#                  25%    500.0  346.000000  350.000000  217.0  250.0
#                  50%    500.0  346.000000  350.000000  217.0  250.0
#                  75%    500.0  346.000000  350.000000  217.0  250.0
#                  max    500.0  346.000000  400.000000  217.0  250.0
# kWhRequested     count    1.0    2.000000   70.000000    1.0    1.0
#                  mean     5.0   10.380000   35.257857   43.4   17.5
#                  std      NaN    4.893179   18.783520    NaN    NaN
#                  min      5.0    6.920000   10.500000   43.4   17.5
#                  25%      5.0    8.650000   22.662500   43.4   17.5
#                  50%      5.0   10.380000   31.500000   43.4   17.5
#                  75%      5.0   12.110000   42.000000   43.4   17.5
#                  max      5.0   13.840000   84.000000   43.4   17.5
# milesRequested   count    1.0    2.000000   70.000000    1.0    1.0
#                  mean    10.0   30.000000   99.471429  200.0   70.0
#                  min     62.000000  193.000000  233.000000  164.000000  451.0
#                  25%     93.500000  217.000000  234.000000  207.000000  451.0
#                  50%     98.500000  241.000000  249.000000  250.000000  451.0
#                  75%    107.250000  265.000000  264.000000  293.000000  451.0
#                  max    109.000000  289.000000  264.000000  336.000000  451.0
#
# userID                    6638        6952
# WhPerMile        count    1.00    4.000000
#                  mean   264.00  285.000000
#                  std       NaN   52.599113
#                  min    264.00  240.000000
#                  25%    264.00  240.000000
#                  50%    264.00  280.000000
#                  75%    264.00  325.000000
#                  max    264.00  340.000000
# kWhRequested     count    1.00    4.000000
#                  mean     5.28   23.500000
#                  std       NaN    7.549834
#                  min      5.28   18.000000
#                  25%      5.28   18.000000
#                  50%      5.28   21.000000
#                  75%      5.28   26.500000
#                  max      5.28   34.000000
# milesRequested   count    1.00    4.000000
#                  mean    20.00   81.250000
#                  std       NaN   12.500000
#                  min     20.00   75.000000
#                  25%     20.00   75.000000
#                  50%     20.00   75.000000
#                  75%     20.00   81.250000
#                  max     20.00  100.000000
# minutesAvailable count    1.00    4.000000
#                  mean   128.00  343.000000
#                  std       NaN   92.811637
#                  min    128.00  274.000000
#                  25%    128.00  300.250000
#                  50%    128.00  309.000000
#                  75%    128.00  351.750000
#                  max    128.00  480.000000
#
# [32 rows x 406 columns]

# %% [markdown]
# # Looking into Smart users (each graph for a single userID)

# %%
# looking into another user

one_user = users[users.userID == 1470]
x = pd.Series(one_user.kWhRequested, name="kWhRequested")
ax = sns.distplot(x)

# %%
# looking into another user

one_user = users[users.userID == 4701]
x = pd.Series(one_user.kWhRequested, name="kWhRequested")
ax = sns.distplot(x)

# %%
one_user.describe()
# Out:
#         WhPerMile  kWhRequested  milesRequested  minutesAvailable  userID
# count   65.000000     65.000000       65.000000         65.000000    65.0
# mean   301.538462     11.569231       38.461538        354.415385  4701.0
# std     12.403473      4.149432       13.945291        103.206391     0.0
# min    300.000000      6.000000       20.000000         82.000000  4701.0
# 25%    300.000000      9.000000       30.000000        307.000000  4701.0
# 50%    300.000000     12.000000       40.000000        397.000000  4701.0
# 75%    300.000000     12.000000       40.000000        400.000000  4701.0
# max    400.000000     30.000000      100.000000        554.000000  4701.0

# %%
# looking into another user

one_user = users[users.userID == 61]
x = pd.Series(one_user.kWhRequested, name="kWhRequested")
ax = sns.distplot(x)

# %%
one_user.describe()
# Out:
#         WhPerMile  kWhRequested  milesRequested  minutesAvailable  userID
# count  309.000000    309.000000      309.000000        309.000000   309.0
# mean   345.307443      7.058252       20.809061        241.181230   891.0
# std     78.245696      1.612604        5.252623         95.620935     0.0
# min    200.000000      3.000000       10.000000         36.000000   891.0
# 25%    300.000000      6.000000       20.000000        206.000000   891.0
# 50%    300.000000      6.000000       20.000000        304.000000   891.0
# 75%    400.000000      8.000000       20.000000        310.000000   891.0
# max    500.000000     12.000000       60.000000        475.000000   891.0

# %%
# looking into another user

one_user = users[users.userID == 162]
x = pd.Series(one_user.kWhRequested, name="kWhRequested")
ax = sns.distplot(x)

# %%
one_user.describe()
# Out:
#         WhPerMile  kWhRequested  milesRequested  minutesAvailable  userID
# count  259.000000    259.000000      259.000000        259.000000   259.0
# mean   486.146718      9.003089       18.629344        142.050193   324.0
# std     92.569321      2.213829        3.167432         55.154903     0.0
# min    400.000000      4.000000       10.000000         38.000000   324.0
# 25%    400.000000      8.000000       20.000000        117.000000   324.0
# 50%    444.000000      8.000000       20.000000        145.000000   324.0
# 75%    600.000000     12.000000       20.000000        167.500000   324.0
# max    600.000000     12.000000       20.000000        695.000000   324.0

# %% [markdown]
# # Finding cars - model Smart

# %%
#finding userIDs for Smart cars
msk_Smart = (users.kWhRequested < 16.5) & (users.WhPerMile < 321)
smart_IDs = users[msk_Smart].userID.unique()


msk_notSmart = charging.kWhDelivered > 16.5
notsmart_IDs = list(charging[msk_notSmart].userID.unique())
notsmart_IDs = notsmart_IDs[1:]
notsmart_IDs = [int(i) for i in notsmart_IDs]
notsmart_IDs.sort()
notsmart_IDs

for i in notsmart_IDs:
    smart_IDs = np.delete(smart_IDs, np.argwhere(smart_IDs == i))


smart_IDs.sort()
smart_IDs
# Out:
# array([  66,   68,  171,  176,  183,  231,  303,  311,  336,  372,  376,
#         420,  433,  444,  516,  562,  593,  609,  634,  674,  675,  724,
#         754,  781,  883,  891,  915,  958, 1083, 1091, 1102, 1126, 1152,
#        1314, 1458, 1526, 1539, 1564, 1752, 1864, 1902, 2213, 2284, 2404,
#        2950, 3143, 3876, 4622, 6049, 6638])

# %%
msk_smart = users.userID.isin(smart_IDs)

# %%
msk_smart
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17129    False
# 17130    False
# 17131    False
# 17132    False
# 17133    False
# Name: userID, Length: 16820, dtype: bool

# %%
Smart = users[msk_smart]
Smart
# Out:
#        WhPerMile  kWhRequested  milesRequested  minutesAvailable  \
# 6            400          8.00              20                60
# 9            400         12.00              30                60
# 10           400         12.00              30               237
# 11           400         20.00              50               237
# 12           400         16.00              40               490
# ...          ...           ...             ...               ...
# 16977        300          6.00              20                61
# 16985        325          6.50              20               196
# 17087        333         16.65              50               625
# 17088        300         15.00              50               625
# 17122        290          5.80              20               120
#
#        paymentRequired  userID                  Modified  \
# 6                 True      66 2018-05-14 13:51:52+00:00
# 9                 True      68 2018-05-16 18:26:58+00:00
# 10                True      68 2018-05-16 18:30:03+00:00
# 11                True      68 2018-05-16 21:56:43+00:00
# 12                True      66 2018-05-21 13:49:54+00:00
# ...                ...     ...                       ...
# 16977             True    4622 2020-03-15 22:38:48+00:00
# 16985             True     562 2020-03-16 15:39:42+00:00
# 17087             True    1526 2020-06-08 16:47:55+00:00
# 17088             True    1526 2020-06-09 16:28:32+00:00
# 17122             True    1539 2020-06-21 23:33:26+00:00
#
#                       Departure
# 6     2018-05-14 14:50:26+00:00
# 9     2018-05-16 19:24:08+00:00
# 10    2018-05-16 22:21:08+00:00
# 11    2018-05-16 22:21:08+00:00
# 12    2018-05-21 21:59:23+00:00
# ...                         ...
#                  mean    21.333333   28.750000   20.00
#                  std      3.437758   13.562027     NaN
#                  min     20.000000   10.000000   20.00
#                  25%     20.000000   25.000000   20.00
#                  50%     20.000000   30.000000   20.00
#                  75%     20.000000   32.500000   20.00
#                  max     30.000000   50.000000   20.00
# minutesAvailable count   45.000000    8.000000    1.00
#                  mean    97.844444  193.875000  128.00
#                  std     38.616974  115.756441     NaN
#                  min     61.000000   63.000000  128.00
#                  25%     61.000000   84.750000  128.00
#                  50%    116.000000  191.500000  128.00
#                  75%    127.000000  284.250000  128.00
#                  max    235.000000  353.000000  128.00
#
# [32 rows x 50 columns]

# %%
ax, fig = plt.subplots(figsize = (16, 8))
ax = plt.hist(Smart.kWhRequested, bins = 100)

# %%
maybe_notsmart = Smart[Smart.kWhRequested > 20]
maybe_notsmart.userID.unique()
# Out:
# array([  66,  231,  303,   68,  593,  609,  674, 1126, 1314,  958,  516,
#         675, 1526,  311,  420,  433,  915, 2950, 1458])

# %%
maybe_notsmart
# Out:
#        WhPerMile  kWhRequested  milesRequested  minutesAvailable  \
# 78           400         28.00              70               544
# 79           400         28.00              70               490
# 153          400         52.00             130               192
# 154          233         60.58             260               196
# 257          250         30.00             120               192
# ...          ...           ...             ...               ...
# 16162        400         24.00              60                60
# 16163        400         24.00              60                60
# 16188        267         26.70             100               174
# 16616        250         22.50              90                90
# 16778        250         52.50             210                90
#
#        paymentRequired  userID                  Modified  \
# 78                True      66 2018-07-02 13:53:09+00:00
# 79                True      66 2018-07-02 18:18:04+00:00
# 153               True     231 2018-08-19 15:22:09+00:00
# 154               True     231 2018-08-19 15:49:53+00:00
# 257               True     231 2018-09-06 01:05:43+00:00
# ...                ...     ...                       ...
# 16162             True    1458 2020-02-13 15:43:55+00:00
# 16163             True    1458 2020-02-13 22:56:48+00:00
# 16188             True     420 2020-02-13 21:40:51+00:00
# 16616             True     311 2020-02-28 20:35:52+00:00
# 16778             True     311 2020-03-06 17:01:14+00:00
#
#                       Departure
# 78    2018-07-02 22:56:23+00:00
# 79    2018-07-02 22:02:23+00:00
# 153   2018-08-19 18:33:37+00:00
# 154   2018-08-19 18:37:37+00:00
# 257   2018-09-06 04:15:55+00:00
# ...                         ...
# 16162 2020-02-13 16:43:55+00:00
# 16163 2020-02-13 16:43:55+00:00
# 16188 2020-02-14 00:32:04+00:00
# 16616 2020-02-28 22:05:27+00:00
# 16778 2020-03-06 18:30:12+00:00
#
# [174 rows x 8 columns]

# %%
ax, fig = plt.subplots(figsize = (16, 8))
ax = plt.hist(Smart.milesRequested, bins = 100)

# %%
ax, fig = plt.subplots(figsize = (16, 8))
ax = plt.hist(Smart.minutesAvailable, bins = 100)

# %% [markdown]
# # Using bootstrapping to check out means distributions for smart drivrs miles requests

# %%
all_data = list(Smart.milesRequested)
len(all_data)
all_data
# Out:
# [20,
#  30,
#  30,
#  50,
#  40,
#  30,
#  50,
#  30,
#  30,
#  30,
#  70,
#  70,
#  40,
#  40,
#  50,
#  50,
#  20,
#  130,
#  260,
#  120,
#  120,
#  40,
#  40,
#  20,
#  20,
#  50,
#  20,
#  20,
#  120,
#  50,
#  30,
#  20,
#  30,
#  50,
#  20,
#  50,
#  50,
#  60,
#  60,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  60,
#  110,
#  80,
#  80,
#  80,
#  10,
#  20,
#  30,
#  20,
#  20,
#  20,
#  80,
#  80,
#  100,
#  100,
#  20,
#  80,
#  80,
#  80,
#  50,
#  70,
#  70,
#  70,
#  70,
#  30,
#  80,
#  80,
#  30,
#  80,
#  30,
#  200,
#  240,
#  40,
#  80,
#  30,
#  20,
#  10,
#  40,
#  80,
#  20,
#  30,
#  30,
#  20,
#  80,
#  30,
#  80,
#  30,
#  30,
#  40,
#  30,
#  60,
#  10,
#  20,
#  60,
#  30,
#  40,
#  70,
#  30,
#  50,
#  50,
#  20,
#  70,
#  30,
#  50,
#  50,
#  40,
#  70,
#  40,
#  50,
#  30,
#  10,
#  40,
#  40,
#  20,
#  20,
#  60,
#  30,
#  20,
#  20,
#  20,
#  20,
#  20,
#  60,
#  20,
#  60,
#  20,
#  60,
#  20,
#  20,
#  30,
#  60,
#  20,
#  60,
#  20,
#  20,
#  40,
#  60,
#  20,
#  60,
#  20,
#  60,
#  20,
#  30,
#  20,
#  20,
#  30,
#  30,
#  40,
#  70,
#  10,
#  20,
#  10,
#  50,
#  40,
#  20,
#  40,
#  20,
#  50,
#  60,
#  30,
#  20,
#  30,
#  20,
#  50,
#  50,
#  50,
#  30,
#  10,
#  20,
#  20,
#  20,
#  30,
#  20,
#  20,
#  20,
#  20,
#  50,
#  50,
#  50,
#  60,
#  40,
#  20,
#  50,
#  50,
#  60,
#  60,
#  60,
#  60,
#  60,
#  60,
#  50,
#  40,
#  20,
#  20,
#  50,
#  50,
#  50,
#  50,
#  50,
#  30,
#  10,
#  50,
#  40,
#  50,
#  20,
#  20,
#  20,
#  40,
#  40,
#  40,
#  60,
#  60,
#  20,
#  70,
#  70,
#  20,
#  20,
#  50,
#  40,
#  70,
#  70,
#  70,
#  70,
#  50,
#  30,
#  30,
#  20,
#  60,
#  60,
#  60,
#  60,
#  60,
#  60,
#  60,
#  60,
#  50,
#  70,
#  40,
#  30,
#  80,
#  80,
#  50,
#  30,
#  30,
#  50,
#  70,
#  40,
#  30,
#  30,
#  30,
#  20,
#  50,
#  50,
#  20,
#  50,
#  50,
#  50,
#  80,
#  20,
#  30,
#  50,
#  20,
#  40,
#  30,
#  50,
#  50,
#  20,
#  40,
#  50,
#  50,
#  50,
#  50,
#  40,
#  20,
#  80,
#  60,
#  50,
#  20,
#  50,
#  50,
#  10,
#  50,
#  40,
#  70,
#  30,
#  60,
#  50,
#  20,
#  10,
#  20,
#  10,
#  10,
#  50,
#  50,
#  50,
#  50,
#  70,
#  30,
#  60,
#  50,
#  20,
#  30,
#  20,
#  20,
#  20,
#  50,
#  70,
#  10,
#  60,
#  40,
#  30,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  30,
#  30,
#  20,
#  30,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  20,
#  20,
#  10,
#  10,
#  20,
#  50,
#  50,
#  20,
#  50,
#  20,
#  20,
#  50,
#  50,
#  80,
#  60,
#  60,
#  70,
#  70,
#  70,
#  30,
#  80,
#  60,
#  20,
#  20,
#  20,
#  20,
#  30,
#  10,
#  20,
#  30,
#  80,
#  20,
#  50,
#  50,
#  50,
#  50,
#  20,
#  20,
#  50,
#  20,
#  20,
#  20,
#  50,
#  20,
#  60,
#  50,
#  50,
#  50,
#  50,
#  30,
#  50,
#  70,
#  70,
#  20,
#  60,
#  70,
#  30,
#  60,
#  60,
#  60,
#  20,
#  10,
#  60,
#  20,
#  50,
#  50,
#  20,
#  10,
#  30,
#  50,
#  30,
#  30,
#  70,
#  80,
#  20,
#  10,
#  10,
#  10,
#  10,
#  60,
#  20,
#  50,
#  20,
#  70,
#  30,
#  70,
#  60,
#  20,
#  20,
#  50,
#  50,
#  50,
#  30,
#  20,
#  50,
#  50,
#  30,
#  80,
#  20,
#  20,
#  30,
#  80,
#  50,
#  50,
#  80,
#  20,
#  80,
#  100,
#  100,
#  20,
#  50,
#  50,
#  30,
#  30,
#  80,
#  20,
#  10,
#  30,
#  50,
#  20,
#  50,
#  50,
#  30,
#  30,
#  40,
#  50,
#  50,
#  80,
#  30,
#  80,
#  60,
#  20,
#  50,
#  50,
#  50,
#  80,
#  100,
#  60,
#  20,
#  100,
#  30,
#  50,
#  30,
#  100,
#  20,
#  20,
#  20,
#  10,
#  50,
#  50,
#  80,
#  30,
#  20,
#  60,
#  100,
#  20,
#  30,
#  30,
#  50,
#  50,
#  60,
#  60,
#  60,
#  60,
#  60,
#  30,
#  50,
#  30,
#  100,
#  80,
#  20,
#  30,
#  20,
#  10,
#  20,
#  20,
#  60,
#  100,
#  30,
#  50,
#  50,
#  50,
#  30,
#  20,
#  50,
#  80,
#  20,
#  60,
#  20,
#  30,
#  20,
#  30,
#  60,
#  10,
#  50,
#  30,
#  60,
#  20,
#  50,
#  80,
#  20,
#  50,
#  20,
#  20,
#  20,
#  60,
#  60,
#  60,
#  60,
#  60,
#  60,
#  10,
#  30,
#  50,
#  50,
#  30,
#  80,
#  20,
#  60,
#  60,
#  20,
#  60,
#  60,
#  60,
#  60,
#  10,
#  50,
#  80,
#  60,
#  30,
#  20,
#  20,
#  60,
#  60,
#  30,
#  60,
#  60,
#  30,
#  30,
#  60,
#  60,
#  20,
#  50,
#  50,
#  30,
#  20,
#  20,
#  20,
#  20,
#  20,
#  60,
#  90,
#  20,
#  50,
#  30,
#  80,
#  20,
#  50,
#  50,
#  20,
#  60,
#  100,
#  100,
#  90,
#  90,
#  20,
#  10,
#  50,
#  30,
#  20,
#  60,
#  20,
#  90,
#  90,
#  10,
#  50,
#  10,
#  20,
#  30,
#  50,
#  80,
#  60,
#  30,
#  20,
#  50,
#  10,
#  90,
#  90,
#  90,
#  50,
#  50,
#  30,
#  80,
#  30,
#  20,
#  90,
#  50,
#  90,
#  30,
#  90,
#  90,
#  30,
#  50,
#  50,
#  50,
#  30,
#  20,
#  50,
#  20,
#  50,
#  50,
#  20,
#  20,
#  20,
#  90,
#  90,
#  20,
#  20,
#  50,
#  50,
#  20,
#  20,
#  30,
#  40,
#  50,
#  80,
#  30,
#  20,
#  90,
#  90,
#  30,
#  20,
#  20,
#  20,
#  20,
#  100,
#  20,
#  100,
#  100,
#  20,
#  50,
#  20,
#  100,
#  20,
#  30,
#  20,
#  80,
#  20,
#  100,
#  30,
#  40,
#  20,
#  100,
#  100,
#  100,
#  20,
#  20,
#  20,
#  20,
#  20,
#  80,
#  100,
#  100,
#  10,
#  20,
#  20,
#  30,
#  20,
#  10,
#  20,
#  20,
#  50,
#  50,
#  60,
#  40,
#  40,
#  80,
#  80,
#  80,
#  50,
#  50,
#  30,
#  30,
#  20,
#  20,
#  20,
#  50,
#  20,
#  80,
#  40,
#  20,
#  20,
#  50,
#  20,
#  30,
#  20,
#  20,
#  50,
#  20,
#  20,
#  40,
#  20,
#  20,
#  80,
#  20,
#  50,
#  20,
#  20,
#  20,
#  80,
#  20,
#  20,
#  30,
#  30,
#  30,
#  100,
#  100,
#  20,
#  50,
#  20,
#  20,
#  20,
#  30,
#  20,
#  30,
#  30,
#  30,
#  20,
#  20,
#  20,
#  100,
#  100,
#  100,
#  30,
#  250,
#  250,
#  30,
#  30,
#  20,
#  20,
#  20,
#  20,
#  10,
#  20,
#  20,
#  20,
#  20,
#  80,
#  10,
#  100,
#  100,
#  20,
#  20,
#  20,
#  10,
#  20,
#  20,
#  20,
#  50,
#  50,
#  50,
#  20,
#  20,
#  20,
#  10,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  20,
#  20,
#  80,
#  100,
#  100,
#  100,
#  50,
#  30,
#  20,
#  80,
#  20,
#  20,
#  10,
#  40,
#  50,
#  50,
#  20,
#  20,
#  20,
#  20,
#  50,
#  80,
#  20,
#  20,
#  20,
#  20,
#  10,
#  100,
#  100,
#  100,
#  100,
#  20,
#  20,
#  20,
#  20,
#  20,
#  30,
#  20,
#  20,
#  10,
#  10,
#  10,
#  20,
#  50,
#  20,
#  20,
#  30,
#  50,
#  20,
#  20,
#  20,
#  10,
#  20,
#  50,
#  20,
#  20,
#  50,
#  20,
#  20,
#  50,
#  30,
#  20,
#  20,
#  10,
#  50,
#  20,
#  80,
#  20,
#  100,
#  50,
#  20,
#  20,
#  20,
#  80,
#  20,
#  20,
#  40,
#  50,
#  20,
#  20,
#  30,
#  20,
#  50,
#  40,
#  20,
#  20,
#  30,
#  30,
#  20,
#  80,
#  20,
#  30,
#  20,
#  20,
#  20,
#  80,
#  30,
#  50,
#  50,
#  30,
#  80,
#  30,
#  80,
#  20,
#  20,
#  80,
#  50,
#  40,
#  20,
#  50,
#  50,
#  50,
#  20,
#  50,
#  60,
#  60,
#  60,
#  60,
#  60,
#  40,
#  10,
#  20,
#  50,
#  80,
#  20,
#  10,
#  50,
#  20,
#  20,
#  20,
#  20,
#  20,
#  20,
#  40,
#  50,
#  50,
#  50,
#  20,
#  20,
#  20,
#  30,
#  30,
#  30,
#  27,
#  33,
#  50,
#  80,
#  80,
#  20,
#  80,
#  50,
#  20,
#  20,
#  20,
#  10,
#  20,
#  50,
#  20,
#  20,
#  20,
#  20,
#  10,
#  50,
#  50,
#  20,
#  20,
#  20,
#  20,
#  20,
#  40,
#  20,
#  20,
#  20,
#  20,
#  20,
#  50,
#  80,
#  20,
#  20,
#  20,
#  60,
#  60,
#  20,
#  20,
#  50,
#  20,
#  ...]

# %%
def bootstrap_mean(data, n_samples = 10000):
    bootsrtap_means = []
    for i in range(n_samples):
        bootstrap_sample = np.random.choice(data, size = len(data), replace = True)
        bootsrtap_means.append(np.mean(bootstrap_sample))
    return bootsrtap_means

# %%
all_boot_means = bootstrap_mean(all_data)

# %%
ax, fig = plt.subplots(figsize = (18, 6))
ax = sns.distplot(all_boot_means)
#ax = plt.hist(all_tesla_boot_means)

# %%
ax, fig = plt.subplots(figsize = (18, 6))
#ax = sns.distplot(all_tesla_boot_means)
ax = plt.hist(all_boot_means)

# %%
#variance of bootstrapped means for all tesla users
all_var = np.var(all_data) 
all_var_boot = np.var(all_boot_means)
boot_mean = np.mean(all_boot_means)

print('All Smart users sample mean: 38.36')
print(f'All Smart users bootsrtap sample mean: {boot_mean}')

print(f'Variance of all Smart users charge request: {all_var}')  #why the hell it is so big???
print(f'Variance of all Smart users means: {all_var_boot}')
# Out:
# All Smart users sample mean: 38.36
# All Smart users bootsrtap sample mean: 36.7694056416882
# Variance of all Smart users charge request: 650.9103033486384
# Variance of all Smart users means: 0.2763896345950523

# %%
#confidence interval for all tesla users
left = np.percentile(all_tesla_boot_means, 2.5)
right = np.percentile(all_tesla_boot_means, 97.5)
left, right
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-bac34220a959> in <module>
#       1 #confidence interval for all tesla users
# ----> 2 left = np.percentile(all_tesla_boot_means, 2.5)
#       3 right = np.percentile(all_tesla_boot_means, 97.5)
#       4 left, right
#
# NameError: name 'all_tesla_boot_means' is not defined

# %% [markdown]
# # Using bootstrapping to check out means distributions for smartdrivrs kWh requests

# %%
all_data_kWh = list(Smart.kWhRequested)
all_kWh_boot_means = bootstrap_mean(all_data_kWh)

ax, fig = plt.subplots(figsize = (18, 6))
ax = sns.distplot(all_kWh_boot_means)

# %%
#variance of bootstrapped means for all tesla users
all_var_kWh = np.var(all_data_kWh)
all_var_boot_kWh = np.var(all_kWh_boot_means)
boot_mean_kWh = np.mean(all_kWh_boot_means)

print('All Smart users sample mean: 10.01')
print(f'All Smart users bootsrtap sample mean: {boot_mean_kWh}')

print(f'Variance of all Smart users charge request: {all_var_kWh}')
print(f'Variance of all Smart users means: {all_var_boot_kWh}')
# Out:
# All Smart users sample mean: 10.01
# All Smart users bootsrtap sample mean: 11.461533765719208
# Variance of all Smart users charge request: 57.765434097885745
# Variance of all Smart users means: 0.02498162518417693

# %%
## finding bootsrtap confidence interval for the sample mean

# %%
left = np.percentile(all_kWh_boot_means, 15)
right = np.percentile(all_kWh_boot_means, 85)
left, right
# Out:
# (11.299097222222223, 11.625115202411715)

# %%
## bootsrtapping one tesla user
